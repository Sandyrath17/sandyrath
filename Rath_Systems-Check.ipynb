# %% [markdown]
# # Systems Check
# ### Sanyukta Rath
# ###### EMAT 62110
#
# Making a list
# - thing one
# 1. Thing one
#
# _italics_ bold

# %% [markdown]
# # My goals for this class
#
# ## What I hope to learn
# I hope to gain a **strong foundational understanding of Python** and how it can be used for *problem-solving, automation, and creative projects*.
#
# ### Specific goals
# 1. Learn how to write **clean and readable code**
# 2. Understand *basic programming logic* and structure
# 3. Become comfortable using **functions and variables**
# 4. Build confidence working in *Jupyter Notebooks*
#
# ## Why this class is important to me
# This class is important to me because it will help me think more **logically** and prepare me to use Python in future academic and professional projects.

# %% [markdown]
# ## Inspiration
# Learning Python excites me because it opens doors to **technology, creativity, and problem-solving**.
#
# ![Cat pic] (https://www.bing.com/images/search?view=detailV2&ccid=7u0POKQ2&id=1DD6397BB53F04C2A763908B099B272DEFAF5028&thid=OIP.7u0POKQ2Uf-DTILt_5hWbwHaFj&mediaurl=https%3a%2f%2f4.bp.blogspot.com%2f-wC6M_4vZRsY%2fT2wQ85IW11I%2fAAAAAAAAGKM%2fy2R4nyW96Rg%2fs1600%2fCat-05.jpg&cdnurl=https%3a%2f%2fth.bing.com%2fth%2fid%2fR.eeed0f38a43651ff834c82edff98566f%3frik%3dKFCv7y0nmwmLkA%26pid%3dImgRaw%26r%3d0&exph=1200&expw=1600&q=cat+pics&FORM=IRPRST&ck=F60F92C64D171E21A6E57ACA731F4E17&selectedIndex=31&itb=0)

# %%
# Variable assignment
name = "Sandy"
goal = "to learn Python and build confidence in coding"

print("My name is", name)
print("My goal is", goal)
# Out:
# My name is Sandy
# My goal is to learn Python and build confidence in coding

# %%
def greet_user(name):
    print("Hello", name)
    return "Greeting complete"

result = greet_user("Sandy")
print(result)
# Out:
# Hello Sandy
# Greeting complete
